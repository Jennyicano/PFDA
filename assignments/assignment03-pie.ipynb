# %% [markdown]
# ## Assignment 3 domains
#
# This Jupyter notebook includes a pie chart showing the email domains of people in the CSV file [people-1000.csv](https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download)
#
# The data has been uploaded as a csv document called people-1000.csv in the assignments/data/ directory.
#
# Author Jennifer Ibanez
#
# ********

# %%
# Data frames. 

import pandas as pd

# Numerical arrays.

import numpy as np

# Plotting. 

import matplotlib.pyplot as plt

# %%
# Load the data of 1000 people

people_df = pd.read_csv("data/people-1000.csv")

# Look at the data.

people_df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
# Get the data related with the email domain

people_df['Email']
# Out:
# 0                pwarner@example.org
# 1      fergusonkatherine@example.net
# 2                fhoward@example.org
# 3              zjohnston@example.com
# 4                   elin@example.net
#                    ...
# 995           lyonsdaisy@example.net
# 996          dariusbryan@example.com
# 997           georgechan@example.org
# 998              wanda04@example.net
# 999          deannablack@example.org
# Name: Email, Length: 1000, dtype: object

# %%
people_df['domain'] = people_df['Email'].str.split('@').str[1]
people_df.head(1000)
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
# Checking the number of people using the 3 different domains.
people_df["domain"].value_counts ()
# Out:
# domain
# example.org    341
# example.com    339
# example.net    320
# Name: count, dtype: int64

# %%
# Get the counts of the different domains in a new variable to be added to the pie chart.
domain_counts = people_df["domain"].value_counts()

# Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Different emails domains')
plt.show()

# %% [markdown]
# The pie chart shows the distribution of different email domains used by the people in the data set.
#
# There are 3 different domains in the data set: example.org is the most common domain, with 341 appearances, followed closely by example.com with 339, and example.net with 320.

# %% [markdown]
# ***********
#
# #### References
#
# Here you can find some of the references links that I took into consideration when doing the task.
#
# 1. [W3 Schools](https://www.w3schools.com/python/matplotlib_pie_charts.asp)
# 2. [matplotlib Pie charts](https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html)
# 3. [pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html#pandas.Series.str.split)
# 4. [Stack Overflow](https://stackoverflow.com)

# %% [markdown]
# **************
#
# End
