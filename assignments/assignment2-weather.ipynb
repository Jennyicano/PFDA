# %% [markdown]
# ## Assignment 2 Weather
#
# In this jupyter notebook called assignment2-weather.ipynb, I created a nice plot of the temperature over time ("dryBulbTemperature_Celsius" ).
#
# Author Jennifer Ibanez
#
# ********

# %%
# Data frames. 

import pandas as pd

# Numerical arrays.

import numpy as np

# Plotting. 

import matplotlib.pyplot as plt

# Seaborn for better plotting.

import seaborn as sns

# %% [markdown]
# Loading the data related with the weather

# %%
# Load the Weather data

df = pd.read_csv("data/weatherreadings1.csv")

# %%
# Look at the data

df
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...

# %%
df['reportStartDateTime']
# Out:
# 0     2024-10-02T16:15:00+00:00
# 1     2024-10-02T16:45:00+00:00
# 2     2024-10-02T17:00:00+00:00
# 3     2024-10-02T17:15:00+00:00
# 4     2024-10-02T17:30:00+00:00
#                 ...
# 84    2024-10-03T14:00:00+00:00
# 85    2024-10-03T14:15:00+00:00
# 86    2024-10-03T14:30:00+00:00
# 87    2024-10-03T14:45:00+00:00
# 88    2024-10-03T15:00:00+00:00
# Name: reportStartDateTime, Length: 89, dtype: object

# %%
# Get the data related with the "dryBulbTemperature_Celsius" to do the plot

df['dryBulbTemperature_Celsius']
# Out:
# 0     15.944444
# 1     15.777778
# 2     15.111111
# 3     14.277778
# 4     13.666667
#         ...
# 84    14.611111
# 85    14.944444
# 86    14.944444
# 87    14.944444
# 88    14.722222
# Name: dryBulbTemperature_Celsius, Length: 89, dtype: float64

# %%
# Plotting the histogram of the Dry Bulb Temperature in Celsius.

Temp_Cels = df['dryBulbTemperature_Celsius']

plt.hist(Temp_Cels, bins=10, color='green', edgecolor='black', alpha=0.7, rwidth=0.78)
plt.xlabel('Temperature Celsius')
plt.ylabel('')
plt.title('dryBulbTemperature_Celsius')

plt.show()

# %%
sns.set(style="whitegrid")

# Convert the 'reportStartDateTime' column to datetime format
df['reportStartDateTime'] = pd.to_datetime(df['reportStartDateTime'], utc=True)

# Convert from UTC to Irish Time (Europe/Dublin)
df['reportStartDateTime'] = df['reportStartDateTime'].dt.tz_convert('Europe/Dublin')

report_SDT = df['reportStartDateTime']
temp_cels = df['dryBulbTemperature_Celsius']

plt.figure(figsize=(20, 8))
plt.plot(report_SDT, temp_cels, color='tab:blue', label='Dry Bulb Temperature (°C)')

# Labeling the plot

plt.title('Dry Bulb Temperature Over Time', fontsize=20, color='black')
plt.xlabel('Report Start Date Time', fontsize=17, color='black')
plt.ylabel('Temperature (°C)', fontsize=17, color='black')
plt.xticks(rotation=55)  
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ***********************
#
# End
