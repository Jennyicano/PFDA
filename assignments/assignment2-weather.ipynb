# %% [markdown]
# ## Assignment 2 Weather
#
# In this jupyter notebook called assignment2-weather.ipynb there is a nice plot of the temperature over time ( "dryBulbTemperature_Celsius" ).
#
# Author Jennifer Ibanez
#
# ********

# %%
# Data frames. 

import pandas as pd

# Numerial arrays.

import numpy as np

# Plotting. 

import matplotlib.pyplot as plt

# %% [markdown]
# Loading the data related with the weather

# %%
# Load the Weather data

df = pd.read_csv("weatherreadings1.cvs")

# %%
# Look at the data

df
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...

# %%
# Get the data related with the "dryBulbTemperature_Celsius" to do the plot

df['dryBulbTemperature_Celsius']
# Out:
# 0     15.944444
# 1     15.777778
# 2     15.111111
# 3     14.277778
# 4     13.666667
#         ...
# 84    14.611111
# 85    14.944444
# 86    14.944444
# 87    14.944444
# 88    14.722222
# Name: dryBulbTemperature_Celsius, Length: 89, dtype: float64

# %%
# Plotting the histogram of the Dry Bulb Temperature in Celsius.

Temp_Cels = df['dryBulbTemperature_Celsius']

plt.hist(Temp_Cels, bins=7, color='green', edgecolor='black', alpha=0.7, rwidth=0.78)
plt.xlabel('Dry Temperature Celsius')
plt.ylabel('')
plt.title('dryBulbTemperature_Celsius')

plt.show()
